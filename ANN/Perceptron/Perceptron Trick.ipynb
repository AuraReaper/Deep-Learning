# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

# %% [markdown]
# **imported the dataset from scikit **

# %%
X, y = make_classification(n_samples=1000, n_features=2, n_informative=1,n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=10)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter' , s = 100)

# %% [markdown]
# **created a perceptron**

# %%
def perecepton(X,y):
  X = np.insert(X,0,1,axis=1)
  weights = np.ones(X.shape[1])
  lr = 0.1

  for i in range(100):
    j = np.random.randint(0,100)
    y_hat = step(np.dot(X[j],weights))
    weights = weights + lr*(y[j]-y_hat)*X[j]

  return weights[0],weights[1:]

# %%
def step(z):
  return 1 if z>0 else 0

# %%
intercept,coef = perecepton(X,y)

# %%
print(intercept,coef)
# Out:
# 0.7000000000000001 [0.67590395 1.31501446]

# %%
m = -(coef[0]/coef[1])
b = -(intercept/coef[1])

# %%
x_input = np.linspace(-3,3,1000)
y_input = m*x_input+b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
